# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0, 10)

# %%
y = x**2

# %%
plt.plot(x, y, "r--")
plt.xlim(0, 4)
plt.ylim(0, 10)
plt.title("TITLE")
plt.xlabel("X label")
plt.ylabel("Y label")
# Out:
# Text(0, 0.5, 'Y label')
